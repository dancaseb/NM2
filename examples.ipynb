# %%
from heat_equation_fem import solve_heat_equation_fem, plot_solution
import numpy as np

# %%
#Example 1
k = 0.01  # Diffusion coefficient
T = 1.0   # Final time

# Define boundary and initial conditions
f0 = lambda t: 0.0  # Left boundary: u(0,t) = 0
f1 = lambda t: 0.0  # Right boundary: u(1,t) = 0
g = lambda x: np.sin(np.pi * x)  # Initial condition: u(x,0) = sin(πx)

# Discretization parameters
nx = 50   # Number of spatial elements
nt = 100  # Number of time steps

# %%
x,t,u = solve_heat_equation_fem(k, T, f0, f1, g, nx, nt)

# %%
plot_solution(x,t,u)

# %%
k = 0.01
T = 1.0

f0 = lambda t: 1.0
f1 = lambda t: 0.0
g = lambda x: 1.0 - x

nx = 50
nt = 100

# %%
x,t,u = solve_heat_equation_fem(k, T, f0, f1, g, nx, nt)

# %%
plot_solution(x,t,u)

# %%
# Example 3
k = 0.01
T = 1.0

f0 = lambda t: np.sin(2 * np.pi * t)
f1 = lambda t: 0.0
g = lambda x: 0.0

nx = 50
nt = 200

# %%
x,t,u = solve_heat_equation_fem(k, T, f0, f1, g, nx, nt)

plot_solution(x,t,u)
